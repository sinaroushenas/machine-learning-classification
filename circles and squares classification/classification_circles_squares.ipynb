# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
image=Image.open("E:/A.I/dataset/2.png")

# %%
img=np.array(image)
print(img.shape)
# Out:
# (64, 64, 4)

# %%
img[0][0]
# Out:
# array([255, 255, 255, 255], dtype=uint8)

# %%
plt.imshow(img)

# %%
img2=img[:,:,0]
img3=img2.reshape(4096)
img3.shape
# Out:
# (4096,)

# %%
x=[]
for i in range (1,21):
    im=Image.open("dataset/"+str(i)+".png")
    p=np.array(im)

    p2=p[:,:,0]
    p2=p2.flatten()
    p2=p2/255
    x = np.append(x,p2, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 x=[]
#       2 for i in range (1,21):
# ----> 3     im=Image.open("dataset/"+str(i)+".png")
#       4     p=np.array(im)
#       6     p2=p[:,:,0]
#
# NameError: name 'Image' is not defined

# %%
x=x.reshape(20,4096)

# %%
y=np.array([
    "circle",
    "circle",
    "circle",
    "circle",
    "circle",
    "circle",
    "circle",
    "circle",
    "circle",
    "circle",
    "square",
    "square",
    "square",
    "square",
    "square",
    "square",
    "square",
    "square",
    "square",
    "square",
])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model= linear_model.LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
out_robot=model.predict(x_test)

# %%
out_robot
# Out:
# array(['square', 'square', 'circle', 'circle'], dtype='<U6')

# %%
y_test
# Out:
# array(['square', 'circle', 'circle', 'circle'], dtype='<U6')

# %%
out_robot==y_test
# Out:
# array([ True, False,  True,  True])

# %%
tst=Image.open("E:/A.I/dataset/14.png")
plt.imshow(tst)

# %%
k1=np.array(tst)
k2=k1[:,:,0]
k2=k2.reshape(4096)
k2=k2/255
k2=[k2]

print(k2)
# Out:
# [array([1., 1., 1., ..., 1., 1., 1.], shape=(4096,))]

# %%
model.predict(k2)
# Out:
# array(['square'], dtype='<U6')
